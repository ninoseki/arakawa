# %%
import arakawa as ar
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Groups and Grid layouts
#
# ::: arakawa.Group
#     options:
#           members:
#               - __init__

# %% [markdown]
# ## Simple 2 column grid

# %%
ar.Group(ar.Text("⬅️ Left side"), ar.Text("➡️ Right side"), columns=2)
# Out:
# <style>
#   #ar- c47dc6d95fd34447a8e9fad59ddc5221 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-c47dc6d95fd34447a8e9fad59ddc5221" srcdoc="<!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8" />
#
# <script src="https://kit.fontawesome.com/256c714d9a.js"></script>
# <link href="https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&display=swap"
#   rel="stylesheet" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css" />
# <script>
#   /* construct the view */
#   const htmlHeader = `<style type="text/css">:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }</style>`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: "VIEW", reportWidthClass: "max-w-screen-xl" };
#   window.reportProps["appData"] = { data: { result: {"view_xml": "\u003cView version=\"1\" fragment=\"false\"\u003e\u003cGroup columns=\"2\" valign=\"top\"\u003e\u003cText\u003e\u003c![CDATA[\u2b05\ufe0f Left side]]\u003e\u003c/Text\u003e\u003cText\u003e\u003c![CDATA[\u27a1\ufe0f Right side]]\u003e\u003c/Text\u003e\u003c/Group\u003e\u003c/View\u003e", "assets": {}} }};
# </script>
# <script type="module">
#   import { mountReport } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   mountReport(window.reportProps);
# </script>
# </head>
# <script>
#   window.isIPythonEmbed = true;
# </script>
#
# <body>
#   <main class="max-w-screen-xl w-full mx-auto">
#     <div id="report" class="w-full"></div>
#   </main>
#   <script src="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js"></script>
# </body>
#
# </html>" style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-c47dc6d95fd34447a8e9fad59ddc5221");
# </script>

# %% [markdown]
# ## Plot and DataTable in a 2 column grid

# %%
import altair as alt
from vega_datasets import data

df = data.iris()
plot = (
    alt.Chart(df)
    .mark_point()
    .encode(x="petalLength:Q", y="petalWidth:Q", color="species:N")
)

ar.Group(ar.Plot(plot), ar.DataTable(df), columns=2)
# Out:
# <style>
#   #ar- 631a47021d7b4ed08358be9c292acd8e {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-631a47021d7b4ed08358be9c292acd8e" srcdoc="<!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8" />
#
# <script src="https://kit.fontawesome.com/256c714d9a.js"></script>
# <link href="https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&display=swap"
#   rel="stylesheet" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css" />
# <script>
#   /* construct the view */
#   const htmlHeader = `<style type="text/css">:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }</style>`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: "VIEW", reportWidthClass: "max-w-screen-xl" };
#   window.reportProps["appData"] = { data: { result: {"view_xml": "\u003cView version=\"1\" fragment=\"false\"\u003e\u003cGroup columns=\"2\" valign=\"top\"\u003e\u003cPlot type=\"application/vnd.vegalite.v5+json\" responsive=\"true\" scale=\"1.0\" src=\"ref://d09da8b899\"/\u003e\u003cDataTable type=\"application/vnd.apache.arrow+binary\" rows=\"150\" columns=\"5\" schema=\"[]\" src=\"ref://57f7f0618e\"/\u003e\u003c/Group\u003e\u003c/View\u003e", "assets": {"d09da8b899": {"src": "data:application/vnd.vegalite.v5+json;base64,...", "hash": "d09da8b899", "size": 21584, "mime": "application/vnd.vegalite.v5+json"}, "57f7f0618e": {"src": "data:application/vnd.apache.arrow+binary;base64,...", "hash": "57f7f0618e", "size": 10736, "mime": "application/vnd.apache.arrow+binary"}}} }};
# </script>
# <script type="module">
#   import { mountReport } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   mountReport(window.reportProps);
# </script>
# </head>
# <script>
#   window.isIPythonEmbed = true;
# </script>
#
# <body>
#   <main class="max-w-screen-xl w-full mx-auto">
#     <div id="report" class="w-full"></div>
#   </main>
#   <script src="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js"></script>
# </body>
#
# </html>" style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-631a47021d7b4ed08358be9c292acd8e");
# </script>

# %% [markdown]
# ## Populating a grid with a list of Blocks
#
# If you're generating your plots programmatically or have a lot of plots, you can pass them into the Group block as a list, using the `blocks` parameter. We can rewrite the previous example as follows:

# %%
import altair as alt
from vega_datasets import data

df = data.iris()
plot = (
    alt.Chart(df)
    .mark_point()
    .encode(x="petalLength:Q", y="petalWidth:Q", color="species:N")
)

# You could also generate these in a loop/function
my_plots = [ar.Plot(plot), ar.DataTable(df)]

ar.Group(blocks=my_plots, columns=2)
# Out:
# <style>
#   #ar- 864c05c7f22944a490d4aab242b1fd67 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-864c05c7f22944a490d4aab242b1fd67" srcdoc="<!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8" />
#
# <script src="https://kit.fontawesome.com/256c714d9a.js"></script>
# <link href="https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&display=swap"
#   rel="stylesheet" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css" />
# <script>
#   /* construct the view */
#   const htmlHeader = `<style type="text/css">:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }</style>`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: "VIEW", reportWidthClass: "max-w-screen-xl" };
#   window.reportProps["appData"] = { data: { result: {"view_xml": "\u003cView version=\"1\" fragment=\"false\"\u003e\u003cGroup columns=\"2\" valign=\"top\"\u003e\u003cPlot type=\"application/vnd.vegalite.v5+json\" responsive=\"true\" scale=\"1.0\" src=\"ref://d09da8b899\"/\u003e\u003cDataTable type=\"application/vnd.apache.arrow+binary\" rows=\"150\" columns=\"5\" schema=\"[]\" src=\"ref://57f7f0618e\"/\u003e\u003c/Group\u003e\u003c/View\u003e", "assets": {"d09da8b899": {"src": "data:application/vnd.vegalite.v5+json;base64,...", "hash": "d09da8b899", "size": 21584, "mime": "application/vnd.vegalite.v5+json"}, "57f7f0618e": {"src": "data:application/vnd.apache.arrow+binary;base64,...", "hash": "57f7f0618e", "size": 10736, "mime": "application/vnd.apache.arrow+binary"}}} }};
# </script>
# <script type="module">
#   import { mountReport } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   mountReport(window.reportProps);
# </script>
# </head>
# <script>
#   window.isIPythonEmbed = true;
# </script>
#
# <body>
#   <main class="max-w-screen-xl w-full mx-auto">
#     <div id="report" class="w-full"></div>
#   </main>
#   <script src="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js"></script>
# </body>
#
# </html>" style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-864c05c7f22944a490d4aab242b1fd67");
# </script>
