# %%
import arakawa as ar
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ::: arakawa.Table

# %% [markdown]
# The Table block takes a pandas DataFrame and renders an HTML table in your app.
#
# !!! info
#     `Table` is the best option for displaying multidimensional DataFrames, as `DataTable` will flatten your data.

# %% [markdown]
# ### Simple Table from DataFrame

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    {
        "A": np.random.normal(-1, 1, 5),
        "B": np.random.normal(1, 2, 5),
    }
)

ar.Table(df)
# Out:
# <style>
#   #ar-28af9a3315e14056b4e7f807a9ca9901 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-28af9a3315e14056b4e7f807a9ca9901" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#   window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cTable type=\&quot;application/vnd.arakawa.table+html\&quot; src=\&quot;ref://3a112387db\&quot;/\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {&quot;3a112387db&quot;: {&quot;src&quot;: &quot;data:application/vnd.arakawa.table+html;base64,...&quot;, &quot;hash&quot;: &quot;3a112387db&quot;, &quot;size&quot;: 812, &quot;mime&quot;: &quot;application/vnd.arakawa.table+html&quot;}}} }};
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-28af9a3315e14056b4e7f807a9ca9901");
# </script>

# %% [markdown]
# ### Styled Table from DataFrame

# %% [markdown]
# If your DataFrame includes [DataFrame Styles](https://pandas.pydata.org/pandas-docs/stable/user\_guide/style.html), these will be included in your app. DataFrame styles allow you create custom formatted tables; for instance, to show trends, highlight cells, add bar charts, or display correlations.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({"A": np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list("BCDE"))], axis=1)

ar.Table(df.style.background_gradient(cmap="viridis"))
# Out:
# <style>
#   #ar-9c0f3c35642a4c12899a1d725ce3a992 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-9c0f3c35642a4c12899a1d725ce3a992" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#   window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cTable type=\&quot;application/vnd.arakawa.table+html\&quot; src=\&quot;ref://a050f071fa\&quot;/\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {&quot;a050f071fa&quot;: {&quot;src&quot;: &quot;data:application/vnd.arakawa.table+html;base64,...&quot;, &quot;hash&quot;: &quot;a050f071fa&quot;, &quot;size&quot;: 10744, &quot;mime&quot;: &quot;application/vnd.arakawa.table+html&quot;}}} }};
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-9c0f3c35642a4c12899a1d725ce3a992");
# </script>

# %% [markdown]
# ::: arakawa.DataTable
#     options:
#           members:
#               - __init__

# %% [markdown]
# ### Simple DataTable from DataFrame

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    {
        "A": np.random.normal(-1, 1, 5000),
        "B": np.random.normal(1, 2, 5000),
    }
)

ar.DataTable(df)
# Out:
# <style>
#   #ar-8b02b08c724c40189455c80d0bf0203f {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-8b02b08c724c40189455c80d0bf0203f" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#   window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cDataTable type=\&quot;application/vnd.apache.arrow+binary\&quot; rows=\&quot;5000\&quot; columns=\&quot;2\&quot; schema=\&quot;[]\&quot; src=\&quot;ref://e6f4b8e52e\&quot;/\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {&quot;e6f4b8e52e&quot;: {&quot;src&quot;: &quot;data:application/vnd.apache.arrow+binary;base64,...&quot;, &quot;hash&quot;: &quot;e6f4b8e52e&quot;, &quot;size&quot;: 108516, &quot;mime&quot;: &quot;application/vnd.apache.arrow+binary&quot;}}} }};
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-8b02b08c724c40189455c80d0bf0203f");
# </script>

# %% [markdown]
# ### Running Queries on DataTable
#
# You can run SQL queries on your datatable if you need more advanced filtering & calculations. In the previous example, if we wanted to show only the rows which had a value A > 0.5, we would write the following (note that `$table` is the builtin table name and cannot be changed):
#
# ```sql
# SELECT * FROM $table
# WHERE A > 0.5
# ```

# %% [markdown]
# ::: arakawa.BigNumber

# %% [markdown]
# ### Simple BigNumber

# %%
ar.BigNumber(heading="Simple Statistic", value=100)
# Out:
# <style>
#   #ar-d3baa4977a2e4d209c263b421ef5bef4 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-d3baa4977a2e4d209c263b421ef5bef4" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#   window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cBigNumber heading=\&quot;Simple Statistic\&quot; value=\&quot;100\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {}} }};
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-d3baa4977a2e4d209c263b421ef5bef4");
# </script>

# %% [markdown]
# ### BigNumber with change indicators

# %%
ar.Group(
    ar.BigNumber(
        heading="Percentage points",
        value="84%",
        change="2%",
        is_upward_change=True,
    ),
    ar.BigNumber(
        heading="Percentage points",
        value="84%",
        change="2%",
        is_upward_change=False,
    ),
    ar.BigNumber(
        heading="Points",
        value="1234",
        change="200",
        is_upward_change=True,
    ),
    ar.BigNumber(
        heading="Points",
        value="1234",
        change="200",
        is_upward_change=False,
    ),
    columns=2,
)
# Out:
# <style>
#   #ar-962148b995c5430996793714c754633e {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-962148b995c5430996793714c754633e" srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
# &lt;meta charset=&quot;UTF-8&quot; /&gt;
#
# &lt;link
#   href=&quot;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&quot;
#   rel=&quot;stylesheet&quot;
# /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css&quot; /&gt;
# &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css&quot; /&gt;
# &lt;script&gt;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&quot;text/css&quot;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = { htmlHeader, isLightProse: false, mode: &quot;VIEW&quot;, reportWidthClass: &quot;max-w-screen-xl&quot; };
#   window.reportProps[&quot;appData&quot;] = { data: { result: {&quot;view_xml&quot;: &quot;\u003cView version=\&quot;1\&quot; fragment=\&quot;false\&quot;\u003e\u003cGroup columns=\&quot;2\&quot; valign=\&quot;top\&quot;\u003e\u003cBigNumber heading=\&quot;Percentage points\&quot; value=\&quot;84%\&quot; change=\&quot;2%\&quot; is_positive_intent=\&quot;true\&quot; is_upward_change=\&quot;true\&quot;/\u003e\u003cBigNumber heading=\&quot;Percentage points\&quot; value=\&quot;84%\&quot; change=\&quot;2%\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003cBigNumber heading=\&quot;Points\&quot; value=\&quot;1234\&quot; change=\&quot;200\&quot; is_positive_intent=\&quot;true\&quot; is_upward_change=\&quot;true\&quot;/\u003e\u003cBigNumber heading=\&quot;Points\&quot; value=\&quot;1234\&quot; change=\&quot;200\&quot; is_positive_intent=\&quot;false\&quot; is_upward_change=\&quot;false\&quot;/\u003e\u003c/Group\u003e\u003c/View\u003e&quot;, &quot;assets&quot;: {}} }};
# &lt;/script&gt;
# &lt;script type=&quot;module&quot;&gt;
#   import { mountReport } from &quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js&quot;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#   &lt;/head&gt;
#   &lt;script&gt;
#     window.isIPythonEmbed = true;
#   &lt;/script&gt;
#   &lt;body&gt;
#     &lt;main class=&quot;max-w-screen-xl w-full mx-auto&quot;&gt;
#       &lt;div id=&quot;report&quot; class=&quot;w-full&quot;&gt;&lt;/div&gt;
#     &lt;/main&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js&quot;&gt;&lt;/script&gt;
#   &lt;/body&gt;
# &lt;/html&gt;
# " style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-962148b995c5430996793714c754633e");
# </script>
