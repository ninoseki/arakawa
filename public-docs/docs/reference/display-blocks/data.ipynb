# %%
import arakawa as ar
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ::: arakawa.Table

# %% [markdown]
# The Table block takes a pandas DataFrame and renders an HTML table in your app.
#
# !!! info
#     `Table` is the best option for displaying multidimensional DataFrames, as `DataTable` will flatten your data.

# %% [markdown]
# ### Simple Table from DataFrame

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    {
        "A": np.random.normal(-1, 1, 5),
        "B": np.random.normal(1, 2, 5),
    }
)

ar.Table(df)
# Out:
# <style>
#   #ar- 8ba4ccca118843a9896345d7e5cdcc62 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-8ba4ccca118843a9896345d7e5cdcc62" srcdoc="<!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8" />
#
# <script src="https://kit.fontawesome.com/256c714d9a.js"></script>
# <link href="https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&display=swap"
#   rel="stylesheet" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css" />
# <script>
#   /* construct the view */
#   const htmlHeader = `<style type="text/css">:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }</style>`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: "VIEW", reportWidthClass: "max-w-screen-xl" };
#   window.reportProps["appData"] = { data: { result: {"view_xml": "\u003cView version=\"1\" fragment=\"false\"\u003e\u003cTable type=\"application/vnd.arakawa.table+html\" src=\"ref://a35fddd514\"/\u003e\u003c/View\u003e", "assets": {"a35fddd514": {"src": "data:application/vnd.arakawa.table+html;base64,...", "hash": "a35fddd514", "size": 812, "mime": "application/vnd.arakawa.table+html"}}} }};
# </script>
# <script type="module">
#   import { mountReport } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   mountReport(window.reportProps);
# </script>
# </head>
# <script>
#   window.isIPythonEmbed = true;
# </script>
#
# <body>
#   <main class="max-w-screen-xl w-full mx-auto">
#     <div id="report" class="w-full"></div>
#   </main>
#   <script src="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js"></script>
# </body>
#
# </html>" style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-8ba4ccca118843a9896345d7e5cdcc62");
# </script>

# %% [markdown]
# ### Styled Table from DataFrame

# %% [markdown]
# If your DataFrame includes [DataFrame Styles](https://pandas.pydata.org/pandas-docs/stable/user\_guide/style.html), these will be included in your app. DataFrame styles allow you create custom formatted tables; for instance, to show trends, highlight cells, add bar charts, or display correlations.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({"A": np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list("BCDE"))], axis=1)

ar.Table(df.style.background_gradient(cmap="viridis"))
# Out:
# <style>
#   #ar- 869533c02d3c42ed82d55b87c99e0ddf {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-869533c02d3c42ed82d55b87c99e0ddf" srcdoc="<!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8" />
#
# <script src="https://kit.fontawesome.com/256c714d9a.js"></script>
# <link href="https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&display=swap"
#   rel="stylesheet" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css" />
# <script>
#   /* construct the view */
#   const htmlHeader = `<style type="text/css">:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }</style>`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: "VIEW", reportWidthClass: "max-w-screen-xl" };
#   window.reportProps["appData"] = { data: { result: {"view_xml": "\u003cView version=\"1\" fragment=\"false\"\u003e\u003cTable type=\"application/vnd.arakawa.table+html\" src=\"ref://b5a72c9371\"/\u003e\u003c/View\u003e", "assets": {"b5a72c9371": {"src": "data:application/vnd.arakawa.table+html;base64,...", "hash": "b5a72c9371", "size": 10740, "mime": "application/vnd.arakawa.table+html"}}} }};
# </script>
# <script type="module">
#   import { mountReport } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   mountReport(window.reportProps);
# </script>
# </head>
# <script>
#   window.isIPythonEmbed = true;
# </script>
#
# <body>
#   <main class="max-w-screen-xl w-full mx-auto">
#     <div id="report" class="w-full"></div>
#   </main>
#   <script src="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js"></script>
# </body>
#
# </html>" style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-869533c02d3c42ed82d55b87c99e0ddf");
# </script>

# %% [markdown]
# ::: arakawa.DataTable
#     options:
#           members:
#               - __init__

# %% [markdown]
# ### Simple DataTable from DataFrame

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    {
        "A": np.random.normal(-1, 1, 5000),
        "B": np.random.normal(1, 2, 5000),
    }
)

ar.DataTable(df)
# Out:
# <style>
#   #ar- 2895ee5b5c64481fa38bb0df1cf47857 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-2895ee5b5c64481fa38bb0df1cf47857" srcdoc="<!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8" />
#
# <script src="https://kit.fontawesome.com/256c714d9a.js"></script>
# <link href="https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&display=swap"
#   rel="stylesheet" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css" />
# <script>
#   /* construct the view */
#   const htmlHeader = `<style type="text/css">:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }</style>`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: "VIEW", reportWidthClass: "max-w-screen-xl" };
#   window.reportProps["appData"] = { data: { result: {"view_xml": "\u003cView version=\"1\" fragment=\"false\"\u003e\u003cDataTable type=\"application/vnd.apache.arrow+binary\" rows=\"5000\" columns=\"2\" schema=\"[]\" src=\"ref://7d9a3c9f65\"/\u003e\u003c/View\u003e", "assets": {"7d9a3c9f65": {"src": "data:application/vnd.apache.arrow+binary;base64,...", "hash": "7d9a3c9f65", "size": 108516, "mime": "application/vnd.apache.arrow+binary"}}} }};
# </script>
# <script type="module">
#   import { mountReport } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   mountReport(window.reportProps);
# </script>
# </head>
# <script>
#   window.isIPythonEmbed = true;
# </script>
#
# <body>
#   <main class="max-w-screen-xl w-full mx-auto">
#     <div id="report" class="w-full"></div>
#   </main>
#   <script src="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js"></script>
# </body>
#
# </html>" style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-2895ee5b5c64481fa38bb0df1cf47857");
# </script>

# %% [markdown]
# ### Running Queries on DataTable
#
# You can run SQL queries on your datatable if you need more advanced filtering & calculations. In the previous example, if we wanted to show only the rows which had a value A > 0.5, we would write the following (note that `$table` is the builtin table name and cannot be changed):
#
# ```sql
# SELECT * FROM $table
# WHERE A > 0.5
# ```

# %% [markdown]
# ::: arakawa.BigNumber

# %% [markdown]
# ### Simple BigNumber

# %%
ar.BigNumber(heading="Simple Statistic", value=100)
# Out:
# <style>
#   #ar- 7e09ca56ce4a42939d00c9738b14b243 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-7e09ca56ce4a42939d00c9738b14b243" srcdoc="<!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8" />
#
# <script src="https://kit.fontawesome.com/256c714d9a.js"></script>
# <link href="https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&display=swap"
#   rel="stylesheet" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css" />
# <script>
#   /* construct the view */
#   const htmlHeader = `<style type="text/css">:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }</style>`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: "VIEW", reportWidthClass: "max-w-screen-xl" };
#   window.reportProps["appData"] = { data: { result: {"view_xml": "\u003cView version=\"1\" fragment=\"false\"\u003e\u003cBigNumber heading=\"Simple Statistic\" value=\"100\" is_positive_intent=\"false\" is_upward_change=\"false\"/\u003e\u003c/View\u003e", "assets": {}} }};
# </script>
# <script type="module">
#   import { mountReport } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   mountReport(window.reportProps);
# </script>
# </head>
# <script>
#   window.isIPythonEmbed = true;
# </script>
#
# <body>
#   <main class="max-w-screen-xl w-full mx-auto">
#     <div id="report" class="w-full"></div>
#   </main>
#   <script src="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js"></script>
# </body>
#
# </html>" style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-7e09ca56ce4a42939d00c9738b14b243");
# </script>

# %% [markdown]
# ### BigNumber with change indicators

# %%
ar.Group(
    ar.BigNumber(
        heading="Percentage points",
        value="84%",
        change="2%",
        is_upward_change=True,
    ),
    ar.BigNumber(
        heading="Percentage points",
        value="84%",
        change="2%",
        is_upward_change=False,
    ),
    ar.BigNumber(
        heading="Points",
        value="1234",
        change="200",
        is_upward_change=True,
    ),
    ar.BigNumber(
        heading="Points",
        value="1234",
        change="200",
        is_upward_change=False,
    ),
    columns=2,
)
# Out:
# <style>
#   #ar- f022ec756eca4eb49133b6354475fda8 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-f022ec756eca4eb49133b6354475fda8" srcdoc="<!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="UTF-8" />
#
# <script src="https://kit.fontawesome.com/256c714d9a.js"></script>
# <link href="https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&display=swap"
#   rel="stylesheet" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.css" />
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/tailwind.css" />
# <script>
#   /* construct the view */
#   const htmlHeader = `<style type="text/css">:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }</style>`;
#   window.reportProps = { htmlHeader, isLightProse: false, isOrg: false, mode: "VIEW", reportWidthClass: "max-w-screen-xl" };
#   window.reportProps["appData"] = { data: { result: {"view_xml": "\u003cView version=\"1\" fragment=\"false\"\u003e\u003cGroup columns=\"2\" valign=\"top\"\u003e\u003cBigNumber heading=\"Percentage points\" value=\"84%\" change=\"2%\" is_positive_intent=\"true\" is_upward_change=\"true\"/\u003e\u003cBigNumber heading=\"Percentage points\" value=\"84%\" change=\"2%\" is_positive_intent=\"false\" is_upward_change=\"false\"/\u003e\u003cBigNumber heading=\"Points\" value=\"1234\" change=\"200\" is_positive_intent=\"true\" is_upward_change=\"true\"/\u003e\u003cBigNumber heading=\"Points\" value=\"1234\" change=\"200\" is_positive_intent=\"false\" is_upward_change=\"false\"/\u003e\u003c/Group\u003e\u003c/View\u003e", "assets": {}} }};
# </script>
# <script type="module">
#   import { mountReport } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   mountReport(window.reportProps);
# </script>
# </head>
# <script>
#   window.isIPythonEmbed = true;
# </script>
#
# <body>
#   <main class="max-w-screen-xl w-full mx-auto">
#     <div id="report" class="w-full"></div>
#   </main>
#   <script src="https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/assets/iframeResizer.contentWindow.min.js"></script>
# </body>
#
# </html>" style="border: none">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.0.1/dist/report/index.es.js";
#   iframeResize({ log: true, checkOrigin: false }, "#ar-f022ec756eca4eb49133b6354475fda8");
# </script>
