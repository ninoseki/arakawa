# %%
import arakawa as ar

# %% [markdown]
# ::: arakawa.TextBox

# %%
ar.TextBox("text")
# Out:
# <style>
#   #ar-8f47e9caa1db4904a37250aa3cb64ada {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-8f47e9caa1db4904a37250aa3cb64ada" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;8f47e9caa1db4904a37250aa3cb64ada&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;_tag&#34;: &#34;TextBox&#34;, &#34;id&#34;: &#34;text&#34;, &#34;name&#34;: &#34;text&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-8f47e9caa1db4904a37250aa3cb64ada");
# </script>

# %% [markdown]
# ::: arakawa.EmailField

# %%
ar.EmailField("email")
# Out:
# <style>
#   #ar-a7b26865466543c581647bcef5b64343 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-a7b26865466543c581647bcef5b64343" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;a7b26865466543c581647bcef5b64343&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;_tag&#34;: &#34;EmailField&#34;, &#34;id&#34;: &#34;email&#34;, &#34;name&#34;: &#34;email&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-a7b26865466543c581647bcef5b64343");
# </script>

# %% [markdown]
# ::: arakawa.HiddenField

# %%
ar.HiddenField("hidden", initial="foo")
# Out:
# <style>
#   #ar-88c2c75c37e948dab306c9c64c96854a {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-88c2c75c37e948dab306c9c64c96854a" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;88c2c75c37e948dab306c9c64c96854a&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;initial&#34;: &#34;foo&#34;, &#34;_tag&#34;: &#34;HiddenField&#34;, &#34;id&#34;: &#34;hidden&#34;, &#34;name&#34;: &#34;hidden&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-88c2c75c37e948dab306c9c64c96854a");
# </script>

# %% [markdown]
# ::: arakawa.PasswordField

# %%
ar.PasswordField("password")
# Out:
# <style>
#   #ar-87e7fa18fc8e49e5a3d9ba8d8fa5b428 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-87e7fa18fc8e49e5a3d9ba8d8fa5b428" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;87e7fa18fc8e49e5a3d9ba8d8fa5b428&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;_tag&#34;: &#34;PasswordField&#34;, &#34;id&#34;: &#34;password&#34;, &#34;name&#34;: &#34;password&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-87e7fa18fc8e49e5a3d9ba8d8fa5b428");
# </script>

# %% [markdown]
# ::: arakawa.SearchField

# %%
ar.SearchField("search")
# Out:
# <style>
#   #ar-1b34c93b6b9846ff993ffbfd9debf2a0 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-1b34c93b6b9846ff993ffbfd9debf2a0" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;1b34c93b6b9846ff993ffbfd9debf2a0&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;_tag&#34;: &#34;SearchField&#34;, &#34;id&#34;: &#34;search&#34;, &#34;name&#34;: &#34;search&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-1b34c93b6b9846ff993ffbfd9debf2a0");
# </script>

# %% [markdown]
# ::: arakawa.TelephoneField

# %%
ar.TelephoneField("tel")
# Out:
# <style>
#   #ar-d483c0f33a00454b88f892a7e11c74ab {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-d483c0f33a00454b88f892a7e11c74ab" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;d483c0f33a00454b88f892a7e11c74ab&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;_tag&#34;: &#34;TelephoneField&#34;, &#34;id&#34;: &#34;tel&#34;, &#34;name&#34;: &#34;tel&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-d483c0f33a00454b88f892a7e11c74ab");
# </script>

# %% [markdown]
# ::: arakawa.URLField

# %%
ar.URLField("url")
# Out:
# <style>
#   #ar-335c3dcbd2044510bd7acbc38dc17d54 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-335c3dcbd2044510bd7acbc38dc17d54" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;335c3dcbd2044510bd7acbc38dc17d54&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;_tag&#34;: &#34;URLField&#34;, &#34;id&#34;: &#34;url&#34;, &#34;name&#34;: &#34;url&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-335c3dcbd2044510bd7acbc38dc17d54");
# </script>
