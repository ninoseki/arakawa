# %%
import arakawa as ar
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ::: arakawa.Text
#     options:
#           members:
#               - __init__

# %% [markdown]
# ### Simple Text From Markdown

# %%
ar.Text("__My awesome markdown__")
# Out:
# <style>
#   #ar-220d515a558f4834a60047607043f2dc {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-220d515a558f4834a60047607043f2dc" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;220d515a558f4834a60047607043f2dc&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;content&#34;: &#34;__My awesome markdown__&#34;, &#34;_tag&#34;: &#34;Text&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-220d515a558f4834a60047607043f2dc");
# </script>

# %% [markdown]
# ### Multi-line Text
#
# To include multi-line text and formatting the words, use triple-quoted string, e.g. `"""Some words"""`

# %%
md = """Quas *diva coeperat usum*; suisque, ab alii, prato. Et cornua frontes puerum,
referam vocassent **umeris**. Dies nec suorum alis adstitit, *temeraria*,
anhelis aliis lacunabant quoque adhuc spissatus illum refugam perterrita in
sonus. Facturus ad montes victima fluctus undae Zancle et nulli; frigida me.
Regno memini concedant argento Aiacis terga, foribusque audit Persephone
serieque, obsidis cupidine qualibet Exadius.

```python
utf_torrent_flash = -1;
urlUpnp -= leakWebE - dslam;
skinCdLdap += sessionCyberspace;
var ascii = address - software_compile;
webFlaming(cable, pathIllegalHtml);```

## Quo exul exsecrere cuique non alti caerulaque

*Optatae o*! Quo et callida et caeleste amorem: nocet recentibus causamque.

- Voce adduntque
- Divesque quam exstinctum revulsus
- Et utrique eunti
- Vos tantum quercum fervet et nec
- Eris pennis maneas quam
"""

ar.Text(md)
# Out:
# <style>
#   #ar-8bc4ee062d05477d9e1fb41c792affac {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-8bc4ee062d05477d9e1fb41c792affac" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;8bc4ee062d05477d9e1fb41c792affac&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;content&#34;: &#34;Quas *diva coeperat usum*; suisque, ab alii, prato. Et cornua frontes puerum,\nreferam vocassent **umeris**. Dies nec suorum alis adstitit, *temeraria*,\nanhelis aliis lacunabant quoque adhuc spissatus illum refugam perterrita in\nsonus. Facturus ad montes victima fluctus undae Zancle et nulli; frigida me.\nRegno memini concedant argento Aiacis terga, foribusque audit Persephone\nserieque, obsidis cupidine qualibet Exadius.\n\n```python\nutf_torrent_flash = -1;\nurlUpnp -= leakWebE - dslam;\nskinCdLdap += sessionCyberspace;\nvar ascii = address - software_compile;\nwebFlaming(cable, pathIllegalHtml);```\n\n## Quo exul exsecrere cuique non alti caerulaque\n\n*Optatae o*! Quo et callida et caeleste amorem: nocet recentibus causamque.\n\n- Voce adduntque\n- Divesque quam exstinctum revulsus\n- Et utrique eunti\n- Vos tantum quercum fervet et nec\n- Eris pennis maneas quam&#34;, &#34;_tag&#34;: &#34;Text&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-8bc4ee062d05477d9e1fb41c792affac");
# </script>

# %% [markdown]
# ### Text-heavy Apps
#
# If your app is text-heavy (such as an blogpost) and it contains multiple other blocks, creating a list of strings and blocks in Python can be cumbersome. To solve this, Arakawa provides a `format` option, which allows you to write a single block of Markdown (either in your app, or in a separate file), and intersperse it with other blocks.
#
# To do this, use double braces to specify where you want your other blocks to appear throughout your text.

# %%
import seaborn as sns
import altair as alt

md = """
For example, if we want to visualize the number of people in each class within the interval we select a point chart between age and fare, we could do something like this.

{{plot}}

Altair allows you to create some extremely interactive plots which do on-the-fly calculations — without even requiring a running Python server!
"""

titanic = sns.load_dataset("titanic")

points = (
    alt.Chart(titanic)
    .mark_point()
    .encode(
        x="age:Q",
        color="class:N",
        y="fare:Q",
    )
    .interactive()
    .properties(width="container")
)

ar.Text(md).format(plot=points)
# Out:
# <style>
#   #ar-18092d349a49444f822fb4f018d241fa {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-18092d349a49444f822fb4f018d241fa" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;18092d349a49444f822fb4f018d241fa&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;blocks&#34;: [{&#34;content&#34;: &#34;For example, if we want to visualize the number of people in each class within the interval we select a point chart between age and fare, we could do something like this.&#34;, &#34;_tag&#34;: &#34;Text&#34;}, {&#34;src&#34;: &#34;ref://39915f7428&#34;, &#34;type&#34;: &#34;application/vnd.vegalite.v5+json&#34;, &#34;responsive&#34;: true, &#34;scale&#34;: 1.0, &#34;_tag&#34;: &#34;Plot&#34;}, {&#34;content&#34;: &#34;Altair allows you to create some extremely interactive plots which do on-the-fly calculations \u2014 without even requiring a running Python server!&#34;, &#34;_tag&#34;: &#34;Text&#34;}], &#34;columns&#34;: 1, &#34;valign&#34;: &#34;top&#34;, &#34;_tag&#34;: &#34;Group&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {&#34;39915f7428&#34;: {&#34;src&#34;: &#34;data:application/vnd.vegalite.v5+json;base64,...&#34;, &#34;hash&#34;: &#34;39915f7428&#34;, &#34;size&#34;: 288544, &#34;mime&#34;: &#34;application/vnd.vegalite.v5+json&#34;}}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-18092d349a49444f822fb4f018d241fa");
# </script>

# %% [markdown]
# ### Text From File

# %% [markdown]
# Alternatively, you can write your article or post in your favourite markdown editor, and pass it in as a file.
#
# ```python
# ar.Text(file="./my_blogpost.md").format(plot=points)
# ```

# %% [markdown]
# ::: arakawa.Code

# %% [markdown]
# ### Simple Code Block

# %%
code = """
function foo(n) {
  return foo(n + 1)
}
"""

ar.Code(code=code, language="javascript")
# Out:
# <style>
#   #ar-6368ff53c7db4be4b6a0448b246694cd {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-6368ff53c7db4be4b6a0448b246694cd" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;6368ff53c7db4be4b6a0448b246694cd&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;content&#34;: &#34;function foo(n) {\n  return foo(n + 1)\n}&#34;, &#34;language&#34;: &#34;javascript&#34;, &#34;_tag&#34;: &#34;Code&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-6368ff53c7db4be4b6a0448b246694cd");
# </script>

# %% [markdown]
# ::: arakawa.Formula

# %% [markdown]
# ### Simple LaTeX Formula

# %%
ar.Formula(r"\frac{1}{\sqrt{x^2 + 1}}")
# Out:
# <style>
#   #ar-4a3ef4fdef8944e8aba84db5248e023d {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-4a3ef4fdef8944e8aba84db5248e023d" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;4a3ef4fdef8944e8aba84db5248e023d&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;content&#34;: &#34;\\frac{1}{\\sqrt{x^2 + 1}}&#34;, &#34;_tag&#34;: &#34;Formula&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-4a3ef4fdef8944e8aba84db5248e023d");
# </script>

# %% [markdown]
# ::: arakawa.HTML

# %% [markdown]
# ### Simple HTML Content

# %%
html = """
<html>
    <style type='text/css'>
        @keyframes example {
            0%   {color: #EEE;}
            25%  {color: #EC4899;}
            50%  {color: #8B5CF6;}
            100% {color: #EF4444;}
        }
        #container {
            background: #1F2937;
            padding: 10em;
        }
        h1 {
            color:#eee;
            animation-name: example;
            animation-duration: 4s;
            animation-iteration-count: infinite;
        }
    </style>
    <div id="container">
      <h1> Welcome to my App </h1>
    </div>
</html>
"""

ar.HTML(html)
# Out:
# <style>
#   #ar-676d0084fcd74e4ba8142ad69b7312ed {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-676d0084fcd74e4ba8142ad69b7312ed" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;676d0084fcd74e4ba8142ad69b7312ed&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;content&#34;: &#34;\u003chtml\u003e\n    \u003cstyle type=\u0027text/css\u0027\u003e\n        @keyframes example {\n            0%   {color: #EEE;}\n            25%  {color: #EC4899;}\n            50%  {color: #8B5CF6;}\n            100% {color: #EF4444;}\n        }\n        #container {\n            background: #1F2937;\n            padding: 10em;\n        }\n        h1 {\n            color:#eee;\n            animation-name: example;\n            animation-duration: 4s;\n            animation-iteration-count: infinite;\n        }\n    \u003c/style\u003e\n    \u003cdiv id=\&#34;container\&#34;\u003e\n      \u003ch1\u003e Welcome to my App \u003c/h1\u003e\n    \u003c/div\u003e\n\u003c/html\u003e&#34;, &#34;sandbox&#34;: &#34;allow-scripts&#34;, &#34;_tag&#34;: &#34;HTML&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-676d0084fcd74e4ba8142ad69b7312ed");
# </script>

# %% [markdown]
# ::: arakawa.Alert

# %% [markdown]
# ### Simple Alert

# %%
ar.Alert("Danger!", mode=ar.AlertMode.DANGER)
# Out:
# <style>
#   #ar-f6c6e81c8fd343c7a3a942f8d973bd33 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-f6c6e81c8fd343c7a3a942f8d973bd33" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;f6c6e81c8fd343c7a3a942f8d973bd33&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;content&#34;: &#34;Danger!&#34;, &#34;border&#34;: true, &#34;mode&#34;: &#34;DANGER&#34;, &#34;_tag&#34;: &#34;Alert&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-f6c6e81c8fd343c7a3a942f8d973bd33");
# </script>

# %% [markdown]
# ::: arakawa.Divider

# %% [markdown]
# ### Simple Divider

# %%
ar.Divider("More")
# Out:
# <style>
#   #ar-cd85b436004041aeb8ef233a3233d355 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-cd85b436004041aeb8ef233a3233d355" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;cd85b436004041aeb8ef233a3233d355&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;content&#34;: &#34;More&#34;, &#34;_tag&#34;: &#34;Divider&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-cd85b436004041aeb8ef233a3233d355");
# </script>
