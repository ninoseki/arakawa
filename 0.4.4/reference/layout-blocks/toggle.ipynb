# %%
import arakawa as ar
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Toggle
#
# ::: arakawa.Toggle

# %% [markdown]
# ## Simple Toggle

# %%
import seaborn as sns

code = """
titanic = sns.load_dataset("titanic")

report = ar.Report(
    "# Titanic overview",
    ar.HTML(
        '<html><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/RMS_Titanic_3.jpg/1280px-RMS_Titanic_3.jpg" style="height:400px;display:flex;margin:auto"></img></html>'
    ),
    ar.Select(
        blocks=[
            ar.Table(titanic.describe(), label="Data Description"),
            ar.DataTable(titanic, label="Whole Dataset"),
            ar.Code(code, label="Source code"),
        ]
    ),
)

report.save(path="select.html")
"""

titanic = sns.load_dataset("titanic")

ar.Blocks(
    "# Titanic overview",
    ar.HTML(
        '<html><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/RMS_Titanic_3.jpg/1280px-RMS_Titanic_3.jpg" style="height:400px;display:flex;margin:auto"></img></html>'
    ),
    ar.Toggle(
        blocks=[
            ar.Table(titanic.describe(), label="Data Description"),
            ar.DataTable(titanic, label="Whole Dataset"),
            ar.Code(code, label="Source code"),
        ]
    ),
)
# Out:
# <style>
#   #ar-b4665524e1e64b8896848d86f6db29bb {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-b4665524e1e64b8896848d86f6db29bb" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
# ...
