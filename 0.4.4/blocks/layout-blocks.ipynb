# %%
import arakawa as ar

# %% [markdown]
# Layout blocks take other blocks as parameters and lay them out. Interactive layout blocks (such as tabs and selects) don't require a backend server and can be used in HTML reports.

# %% [markdown]
# ## Group

# %%
import altair as alt
from vega_datasets import data

df = data.iris()

plot_base = alt.Chart(df).mark_point().interactive()

ar.Group(
    "Iris analysis",
    ar.Select(
       ar.DataTable(df, label='Data'),
       ar.Group(
           ar.Plot(plot_base.encode(x='sepalLength', y='sepalWidth', color='species')),
           ar.Plot(plot_base.encode(x='petalLength', y='petalWidth', color='species')),
           columns=2,
           label='Plots'
       )
    )
)
# Out:
# <style>
#   #ar-37cce1a9916d42b1b00a2c70a25fbcc8 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-37cce1a9916d42b1b00a2c70a25fbcc8" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;37cce1a9916d42b1b00a2c70a25fbcc8&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;blocks&#34;: [{&#34;content&#34;: &#34;Iris analysis&#34;, &#34;_tag&#34;: &#34;Text&#34;}, {&#34;blocks&#34;: [{&#34;label&#34;: &#34;Data&#34;, &#34;src&#34;: &#34;ref://b9f51c92e2&#34;, &#34;type&#34;: &#34;application/vnd.apache.arrow+binary&#34;, &#34;rows&#34;: 150, &#34;columns&#34;: 5, &#34;_tag&#34;: &#34;DataTable&#34;}, {&#34;label&#34;: &#34;Plots&#34;, &#34;blocks&#34;: [{&#34;src&#34;: &#34;ref://4e5d071e8c&#34;, &#34;type&#34;: &#34;application/vnd.vegalite.v5+json&#34;, &#34;responsive&#34;: true, &#34;scale&#34;: 1.0, &#34;_tag&#34;: &#34;Plot&#34;}, {&#34;src&#34;: &#34;ref://cacac7f80d&#34;, &#34;type&#34;: &#34;application/vnd.vegalite.v5+json&#34;, &#34;responsive&#34;: true, &#34;scale&#34;: 1.0, &#34;_tag&#34;: &#34;Plot&#34;}], &#34;columns&#34;: 2, &#34;valign&#34;: &#34;top&#34;, &#34;_tag&#34;: &#34;Group&#34;}], &#34;type&#34;: &#34;tabs&#34;, &#34;_tag&#34;: &#34;Select&#34;}], &#34;columns&#34;: 1, &#34;valign&#34;: &#34;top&#34;, &#34;_tag&#34;: &#34;Group&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {&#34;b9f51c92e2&#34;: {&#34;src&#34;: &#34;data:application/vnd.apache.arrow+binary;base64,...&#34;, &#34;hash&#34;: &#34;b9f51c92e2&#34;, &#34;size&#34;: 10808, &#34;mime&#34;: &#34;application/vnd.apache.arrow+binary&#34;}, &#34;4e5d071e8c&#34;: {&#34;src&#34;: &#34;data:application/vnd.vegalite.v5+json;base64,...&#34;, &#34;hash&#34;: &#34;4e5d071e8c&#34;, &#34;size&#34;: 21724, &#34;mime&#34;: &#34;application/vnd.vegalite.v5+json&#34;}, &#34;cacac7f80d&#34;: {&#34;src&#34;: &#34;data:application/vnd.vegalite.v5+json;base64,...&#34;, &#34;hash&#34;: &#34;cacac7f80d&#34;, &#34;size&#34;: 21724, &#34;mime&#34;: &#34;application/vnd.vegalite.v5+json&#34;}}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-37cce1a9916d42b1b00a2c70a25fbcc8");
# </script>

# %% [markdown]
# This includes columns:

# %%
ar.Group(
    ar.BigNumber(heading="Left", value="1234"),
    ar.BigNumber(heading="Middle", value="4321"),
    ar.BigNumber(heading="Right", value="2314"),
    columns=3,
)
# Out:
# <style>
#   #ar-8c7d5ab5072c49108028d844255a1097 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-8c7d5ab5072c49108028d844255a1097" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;8c7d5ab5072c49108028d844255a1097&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;blocks&#34;: [{&#34;heading&#34;: &#34;Left&#34;, &#34;value&#34;: &#34;1234&#34;, &#34;isPositiveIntent&#34;: false, &#34;isUpwardChange&#34;: false, &#34;_tag&#34;: &#34;BigNumber&#34;}, {&#34;heading&#34;: &#34;Middle&#34;, &#34;value&#34;: &#34;4321&#34;, &#34;isPositiveIntent&#34;: false, &#34;isUpwardChange&#34;: false, &#34;_tag&#34;: &#34;BigNumber&#34;}, {&#34;heading&#34;: &#34;Right&#34;, &#34;value&#34;: &#34;2314&#34;, &#34;isPositiveIntent&#34;: false, &#34;isUpwardChange&#34;: false, &#34;_tag&#34;: &#34;BigNumber&#34;}], &#34;columns&#34;: 3, &#34;valign&#34;: &#34;top&#34;, &#34;_tag&#34;: &#34;Group&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-8c7d5ab5072c49108028d844255a1097");
# </script>

# %% [markdown]
# ## Select

# %%
ar.Select(
    blocks=[
        ar.Text("Hello World 1", label="Page 1"),
        ar.Text("Hello World 2", label="Page 2"),
        ar.Text("Hello World 3", label="Page 3"),
    ]
)
# Out:
# <style>
#   #ar-db1cf036b4d5477ea49a1a1ba8b9d9c7 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-db1cf036b4d5477ea49a1a1ba8b9d9c7" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;db1cf036b4d5477ea49a1a1ba8b9d9c7&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;blocks&#34;: [{&#34;content&#34;: &#34;Hello World 1&#34;, &#34;label&#34;: &#34;Page 1&#34;, &#34;_tag&#34;: &#34;Text&#34;}, {&#34;content&#34;: &#34;Hello World 2&#34;, &#34;label&#34;: &#34;Page 2&#34;, &#34;_tag&#34;: &#34;Text&#34;}, {&#34;content&#34;: &#34;Hello World 3&#34;, &#34;label&#34;: &#34;Page 3&#34;, &#34;_tag&#34;: &#34;Text&#34;}], &#34;type&#34;: &#34;tabs&#34;, &#34;_tag&#34;: &#34;Select&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-db1cf036b4d5477ea49a1a1ba8b9d9c7");
# </script>

# %% [markdown]
# ## Nesting
#
# Layout blocks can be arbitrarily nested, allowing you to create complex user interfaces.

# %%
ar.Group(
    ar.Text("This is the left side of a two-column layout"),
    ar.Group(
        ar.Text("This is the right side of a two-column layout"),
        ar.Text("Below we have three tabs with different content"),
        ar.Select(
            blocks=[
                ar.Text("Hello World 1", label="Page 1"),
                ar.Text("Hello World 2", label="Page 2"),
                ar.Text("Hello World 3", label="Page 3"),
            ]
        ),
    ),
    columns=2,
)
# Out:
# <style>
#   #ar-bb7f04b582954b5c940e5972aceca432 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-bb7f04b582954b5c940e5972aceca432" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;bb7f04b582954b5c940e5972aceca432&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;blocks&#34;: [{&#34;content&#34;: &#34;This is the left side of a two-column layout&#34;, &#34;_tag&#34;: &#34;Text&#34;}, {&#34;blocks&#34;: [{&#34;content&#34;: &#34;This is the right side of a two-column layout\n\nBelow we have three tabs with different content&#34;, &#34;_tag&#34;: &#34;Text&#34;}, {&#34;blocks&#34;: [{&#34;content&#34;: &#34;Hello World 1&#34;, &#34;label&#34;: &#34;Page 1&#34;, &#34;_tag&#34;: &#34;Text&#34;}, {&#34;content&#34;: &#34;Hello World 2&#34;, &#34;label&#34;: &#34;Page 2&#34;, &#34;_tag&#34;: &#34;Text&#34;}, {&#34;content&#34;: &#34;Hello World 3&#34;, &#34;label&#34;: &#34;Page 3&#34;, &#34;_tag&#34;: &#34;Text&#34;}], &#34;type&#34;: &#34;tabs&#34;, &#34;_tag&#34;: &#34;Select&#34;}], &#34;columns&#34;: 1, &#34;valign&#34;: &#34;top&#34;, &#34;_tag&#34;: &#34;Group&#34;}], &#34;columns&#34;: 2, &#34;valign&#34;: &#34;top&#34;, &#34;_tag&#34;: &#34;Group&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-bb7f04b582954b5c940e5972aceca432");
# </script>

# %% [markdown]
# ## Compute
#
# Compute block is for composing an HTML form with control blocks.

# %%
ar.Compute(
    ar.TextBox("text"),
    ar.NumberBox("number")
)
# Out:
# <style>
#   #ar-5cf853e4bdd049538a884e0596e66c0b {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-5cf853e4bdd049538a884e0596e66c0b" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;5cf853e4bdd049538a884e0596e66c0b&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;blocks&#34;: [{&#34;_tag&#34;: &#34;TextBox&#34;, &#34;id&#34;: &#34;text&#34;, &#34;name&#34;: &#34;text&#34;}, {&#34;_tag&#34;: &#34;NumberBox&#34;, &#34;id&#34;: &#34;number&#34;, &#34;name&#34;: &#34;number&#34;}], &#34;action&#34;: &#34;&#34;, &#34;method&#34;: &#34;GET&#34;, &#34;_tag&#34;: &#34;Compute&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-5cf853e4bdd049538a884e0596e66c0b");
# </script>

# %% [markdown]
# ## Available Blocks
#
# Check out more layout block examples in the API Reference:
#
# - [`ar.Group`](../../reference/layout-blocks/group/)
# - [`ar.Page`](../../reference/layout-blocks/page/)
# - [`ar.Select`](../../reference/layout-blocks/select/)
# - [`ar.Toggle`](../../reference/layout-blocks/toggle/)
# - [`ar.Compute`](../../reference/layout-blocks/compute/)
