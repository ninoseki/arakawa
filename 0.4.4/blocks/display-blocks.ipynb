# %%
import arakawa as ar

# %% [markdown]
# The first category of blocks are Display Blocks, which take existing Python objects (such pandas DataFrames, plots, and Markdown) and display them.  For instance, Arakawa provides a `DataTable` block that takes a pandas `DataFrame`, and displays it as an interactive table in your report or app.
#
# Arakawa supports the following blocks.
#
# ## Tables And Data
#
# These blocks present and highlight data.
#
# Take advantage of `pandas` and the `Styler` class for finer control over table presentation:

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({"A": np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list("BCDE"))], axis=1)

ar.Table(df.style.background_gradient(cmap="viridis"))
# Out:
# <style>
#   #ar-075a33fc8ee14fe78fb266cb9ff559a3 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-075a33fc8ee14fe78fb266cb9ff559a3" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;075a33fc8ee14fe78fb266cb9ff559a3&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;src&#34;: &#34;ref://1cd7b42ce2&#34;, &#34;type&#34;: &#34;application/vnd.arakawa.table+html&#34;, &#34;_tag&#34;: &#34;Table&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {&#34;1cd7b42ce2&#34;: {&#34;src&#34;: &#34;data:application/vnd.arakawa.table+html;base64,...&#34;, &#34;hash&#34;: &#34;1cd7b42ce2&#34;, &#34;size&#34;: 10740, &#34;mime&#34;: &#34;application/vnd.arakawa.table+html&#34;}}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-075a33fc8ee14fe78fb266cb9ff559a3");
# </script>

# %% [markdown]
# Share large datasets complete with interactivity that enables sorting, filtering, and advanced analysis using SQL:

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    {
        "A": np.random.normal(-1, 1, 5000),
        "B": np.random.normal(1, 2, 5000),
    }
)

ar.DataTable(df)
# Out:
# <style>
#   #ar-75ad091d8a0c4fcc8b7aa0b97c3d9e61 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-75ad091d8a0c4fcc8b7aa0b97c3d9e61" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;75ad091d8a0c4fcc8b7aa0b97c3d9e61&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;src&#34;: &#34;ref://7cdbebbc8c&#34;, &#34;type&#34;: &#34;application/vnd.apache.arrow+binary&#34;, &#34;rows&#34;: 5000, &#34;columns&#34;: 2, &#34;_tag&#34;: &#34;DataTable&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {&#34;7cdbebbc8c&#34;: {&#34;src&#34;: &#34;data:application/vnd.apache.arrow+binary;base64,...&#34;, &#34;hash&#34;: &#34;7cdbebbc8c&#34;, &#34;size&#34;: 108560, &#34;mime&#34;: &#34;application/vnd.apache.arrow+binary&#34;}}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-75ad091d8a0c4fcc8b7aa0b97c3d9e61");
# </script>

# %% [markdown]
# Or highlight key metrics with more than just plain text:

# %%
ar.Group(
    ar.BigNumber(
        heading="Percentage points",
        value="84%",
        change="2%",
        is_upward_change=True,
    ),
    ar.BigNumber(
        heading="Percentage points",
        value="84%",
        change="2%",
        is_upward_change=False,
    ),
    ar.BigNumber(
        heading="Points",
        value="1234",
        change="200",
        is_upward_change=True,
    ),
    ar.BigNumber(
        heading="Points",
        value="1234",
        change="200",
        is_upward_change=False,
    ),
    columns=2,
)
# Out:
# <style>
#   #ar-fad6e56b80c349338a96e333a46f254a {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-fad6e56b80c349338a96e333a46f254a" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;fad6e56b80c349338a96e333a46f254a&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;blocks&#34;: [{&#34;heading&#34;: &#34;Percentage points&#34;, &#34;value&#34;: &#34;84%&#34;, &#34;change&#34;: &#34;2%&#34;, &#34;isPositiveIntent&#34;: true, &#34;isUpwardChange&#34;: true, &#34;_tag&#34;: &#34;BigNumber&#34;}, {&#34;heading&#34;: &#34;Percentage points&#34;, &#34;value&#34;: &#34;84%&#34;, &#34;change&#34;: &#34;2%&#34;, &#34;isPositiveIntent&#34;: false, &#34;isUpwardChange&#34;: false, &#34;_tag&#34;: &#34;BigNumber&#34;}, {&#34;heading&#34;: &#34;Points&#34;, &#34;value&#34;: &#34;1234&#34;, &#34;change&#34;: &#34;200&#34;, &#34;isPositiveIntent&#34;: true, &#34;isUpwardChange&#34;: true, &#34;_tag&#34;: &#34;BigNumber&#34;}, {&#34;heading&#34;: &#34;Points&#34;, &#34;value&#34;: &#34;1234&#34;, &#34;change&#34;: &#34;200&#34;, &#34;isPositiveIntent&#34;: false, &#34;isUpwardChange&#34;: false, &#34;_tag&#34;: &#34;BigNumber&#34;}], &#34;columns&#34;: 2, &#34;valign&#34;: &#34;top&#34;, &#34;_tag&#34;: &#34;Group&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-fad6e56b80c349338a96e333a46f254a");
# </script>

# %% [markdown]
# Check out [Tables and data](../../reference/display-blocks/text/) in the API Reference.
#
# !!! tip
#     Table and DataTable support both Pandas and Polars data frames.
#
# ## Plots And Visualizations
#
# Arakawa supports all major Python visualization libraries, from bubble charts with Altair:

# %%
import altair as alt
import pandas as pd
from vega_datasets import data as vega_data

gap = pd.read_json(vega_data.gapminder.url)

select_year = alt.selection_point(
    name="select",
    fields=["year"],
    value={"year": 1955},
    bind=alt.binding_range(min=1955, max=2005, step=5),
)

alt_chart = (
    alt.Chart(gap)
    .mark_point(filled=True)
    .encode(
        alt.X("fertility", scale=alt.Scale(zero=False)),
        alt.Y("life_expect", scale=alt.Scale(zero=False)),
        alt.Size("pop:Q"),
        alt.Color("cluster:N"),
        alt.Order("pop:Q", sort="descending"),
    )
    .add_params(select_year)
    .transform_filter(select_year)
)

ar.Plot(alt_chart)
# Out:
# <style>
#   #ar-285a625b45714e308a7d3a0f205db46c {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-285a625b45714e308a7d3a0f205db46c" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;285a625b45714e308a7d3a0f205db46c&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;src&#34;: &#34;ref://7676810a71&#34;, &#34;type&#34;: &#34;application/vnd.vegalite.v5+json&#34;, &#34;responsive&#34;: true, &#34;scale&#34;: 1.0, &#34;_tag&#34;: &#34;Plot&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {&#34;7676810a71&#34;: {&#34;src&#34;: &#34;data:application/vnd.vegalite.v5+json;base64,...&#34;, &#34;hash&#34;: &#34;7676810a71&#34;, &#34;size&#34;: 104968, &#34;mime&#34;: &#34;application/vnd.vegalite.v5+json&#34;}}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-285a625b45714e308a7d3a0f205db46c");
# </script>

# %% [markdown]
# All the way to geographic plots with Folium:

# %%
import folium

m = folium.Map(location=[45.5236, -122.6750])

ar.Plot(m)
# Out:
# <style>
#   #ar-ac55e442c0764ddaa87e9c881b3303c2 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-ac55e442c0764ddaa87e9c881b3303c2" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;ac55e442c0764ddaa87e9c881b3303c2&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;src&#34;: &#34;ref://58b60fdfce&#34;, &#34;type&#34;: &#34;application/vnd.folium+html&#34;, &#34;responsive&#34;: true, &#34;scale&#34;: 1.0, &#34;_tag&#34;: &#34;Plot&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {&#34;58b60fdfce&#34;: {&#34;src&#34;: &#34;data:application/vnd.folium+html;base64,...&#34;, &#34;hash&#34;: &#34;58b60fdfce&#34;, &#34;size&#34;: 4448, &#34;mime&#34;: &#34;application/vnd.folium+html&#34;}}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-ac55e442c0764ddaa87e9c881b3303c2");
# </script>

# %% [markdown]
# Check out [Plots and visualizations](../../reference/display-blocks/plots/) in the API Reference.

# %% [markdown]
# ## Network
#
# Arakawa supports [sigma.js](https://www.sigmajs.org/) based network visualization.
#
# - `Sigma` for setting sigma.js graph data as it is.
# - `Network` for converting an [NetworkX]() graph as a sigma.js compatible data.

# %%
import json

with open("./artic.json") as f:
    data = json.load(f)

max_size = max([node_data["attributes"]["size"] for node_data in data["nodes"]])
for node_data in data["nodes"]:
    node_data["attributes"]["size"] /= max_size
    node_data["attributes"]["size"] *= 20
    node_data["attributes"]["size"] += 5

ar.Sigma(
    data,
    layout_settings={
        "outbound_attraction_distribution": True,
        "barnes_hut_optimize": True,
        "adjust_sizes": True,
        "lin_log_mode": True,
    },
)
# Out:
# <style>
#   #ar-c4d4263e90bf4848b99238bc947f7d03 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-c4d4263e90bf4848b99238bc947f7d03" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;c4d4263e90bf4848b99238bc947f7d03&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;data&#34;: {&#34;attributes&#34;: {&#34;creator&#34;: &#34;Gephi 0.10.1&#34;}, &#34;options&#34;: {&#34;multi&#34;: false, &#34;allowSelfLoops&#34;: true, &#34;type&#34;: &#34;directed&#34;}, &#34;nodes&#34;: [{&#34;key&#34;: &#34;53&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;Changement Climatique&#34;, &#34;x&#34;: 639.0149, &#34;y&#34;: -703.6634, &#34;size&#34;: 25.0, &#34;color&#34;: &#34;#66ff66&#34;, &#34;0&#34;: &#34;n53&#34;, &#34;1&#34;: &#34;Changement Climatique&#34;, &#34;2&#34;: 209}}, {&#34;key&#34;: &#34;79&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;Climatic Change&#34;, &#34;x&#34;: -308.02515, &#34;y&#34;: 1221.1296, &#34;size&#34;: 20.91433759143376, &#34;color&#34;: &#34;#66ff66&#34;, &#34;0&#34;: &#34;n79&#34;, &#34;1&#34;: &#34;Climatic Change&#34;, &#34;2&#34;: 170}}, {&#34;key&#34;: &#34;65&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;Effet De Serre&#34;, &#34;x&#34;: 865.82855, &#34;y&#34;: -903.2288, &#34;size&#34;: 18.875474387547442, &#34;color&#34;: &#34;#66ff66&#34;, &#34;0&#34;: &#34;n65&#34;, &#34;1&#34;: &#34;Effet De Serre&#34;, &#34;2&#34;: 143}}, {&#34;key&#34;: &#34;1&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;New York&#34;, &#34;x&#34;: -752.00604, &#34;y&#34;: 236.44363, &#34;size&#34;: 17.87033528703353, &#34;color&#34;: &#34;#ff3333&#34;, &#34;0&#34;: &#34;n1&#34;, &#34;1&#34;: &#34;New York&#34;, &#34;2&#34;: 143}}, {&#34;key&#34;: &#34;50&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;R\u00e9chauffement Climatique&#34;, &#34;x&#34;: 480.57895, &#34;y&#34;: -476.38458, &#34;size&#34;: 16.326397132639713, &#34;color&#34;: &#34;#66ff66&#34;, &#34;0&#34;: &#34;n50&#34;, &#34;1&#34;: &#34;R\u00e9chauffement Climatique&#34;, &#34;2&#34;: 118}}, {&#34;key&#34;: &#34;82&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;Union Europ\u00e9enne&#34;, &#34;x&#34;: 77.16729, &#34;y&#34;: -1303.9236, &#34;size&#34;: 13.902965690296568, &#34;color&#34;: &#34;#ff3333&#34;, &#34;0&#34;: &#34;n82&#34;, &#34;1&#34;: &#34;Union Europ\u00e9enne&#34;, &#34;2&#34;: 104}}, {&#34;key&#34;: &#34;68&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;Activit\u00e9 Humaine&#34;, &#34;x&#34;: 1020.4861, &#34;y&#34;: -997.3567, &#34;size&#34;: 12.844332784433279, &#34;color&#34;: &#34;#66ff66&#34;, &#34;0&#34;: &#34;n68&#34;, &#34;1&#34;: &#34;Activit\u00e9 Humaine&#34;, &#34;2&#34;: 88}}, {&#34;key&#34;: &#34;48&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;Oc\u00e9an Arctique&#34;, &#34;x&#34;: 28.159622, &#34;y&#34;: -147.40862, &#34;size&#34;: 11.587060658706065, &#34;color&#34;: &#34;#00cccc&#34;, &#34;0&#34;: &#34;n48&#34;, &#34;1&#34;: &#34;Oc\u00e9an Arctique&#34;, &#34;2&#34;: 73}}, {&#34;key&#34;: &#34;49&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;Pole Nord&#34;, &#34;x&#34;: 142.79425, &#34;y&#34;: 98.24791, &#34;size&#34;: 11.380125638012565, &#34;color&#34;: &#34;#00cccc&#34;, &#34;0&#34;: &#34;n49&#34;, &#34;1&#34;: &#34;Pole Nord&#34;, &#34;2&#34;: 78}}, {&#34;key&#34;: &#34;109&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;Ressource Naturelle&#34;, &#34;x&#34;: 372.73026, &#34;y&#34;: -1337.6946, &#34;size&#34;: 9.770703277070329, &#34;color&#34;: &#34;#009900&#34;, &#34;0&#34;: &#34;n109&#34;, &#34;1&#34;: &#34;Ressource Naturelle&#34;, &#34;2&#34;: 62}}, {&#34;key&#34;: &#34;61&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;Calotte Glaciaire&#34;, &#34;x&#34;: 591.7032, &#34;y&#34;: -123.897644, &#34;size&#34;: 8.826222382622237, &#34;color&#34;: &#34;#99ffff&#34;, &#34;0&#34;: &#34;n61&#34;, &#34;1&#34;: &#34;Calotte Glaciaire&#34;, &#34;2&#34;: 45}}, {&#34;key&#34;: &#34;104&#34;, &#34;attributes&#34;: {&#34;label&#34;: &#34;Energie Renouvelable&#34;, &#34;x&#34;: 817.02045, &#34;y&#34;: -1168.9274, &#34;size&#34;: 8.826222382622237, &#34;color&#34;: &#34;#009900&#34;, &#34;0&#34;: &#34;n104&#34;, &#34;1&#34;: &#34;Ene ...

# %%
import networkx as nx

G = nx.karate_club_graph()
for ix, node in enumerate(list(G.nodes())):
    G.nodes[node]["label"] = str(ix)
    G.nodes[node]["size"] = G.degree(node)

ar.NetworkX(
    G,
    layout_settings={
        "outbound_attraction_distribution": True,
        "barnes_hut_optimize": True,
        "adjust_sizes": True,
        "lin_log_mode": True,
    },
)
# Out:
# <style>
#   #ar-c17284e4001041169e266aa455c6baa7 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-c17284e4001041169e266aa455c6baa7" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;c17284e4001041169e266aa455c6baa7&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;data&#34;: {&#34;options&#34;: {&#34;type&#34;: &#34;undirected&#34;, &#34;multi&#34;: false, &#34;allowSelfLoops&#34;: true}, &#34;attributes&#34;: {&#34;name&#34;: &#34;Zachary\u0027s Karate Club&#34;}, &#34;nodes&#34;: [{&#34;key&#34;: 0, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;0&#34;, &#34;size&#34;: 16, &#34;x&#34;: 0.3593874798666587, &#34;y&#34;: 0.005331821394894261}}, {&#34;key&#34;: 1, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;1&#34;, &#34;size&#34;: 9, &#34;x&#34;: 0.21401666899625646, &#34;y&#34;: 0.013730135602342363}}, {&#34;key&#34;: 2, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;2&#34;, &#34;size&#34;: 10, &#34;x&#34;: 0.04879292980446005, &#34;y&#34;: -0.09306692750661516}}, {&#34;key&#34;: 3, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;3&#34;, &#34;size&#34;: 6, &#34;x&#34;: 0.29018509149956573, &#34;y&#34;: -0.19586023915157982}}, {&#34;key&#34;: 4, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;4&#34;, &#34;size&#34;: 3, &#34;x&#34;: 0.6099664733261773, &#34;y&#34;: 0.16176931334157255}}, {&#34;key&#34;: 5, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;5&#34;, &#34;size&#34;: 4, &#34;x&#34;: 0.7539658452361834, &#34;y&#34;: 0.15186421386894117}}, {&#34;key&#34;: 6, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;6&#34;, &#34;size&#34;: 4, &#34;x&#34;: 0.7572169408419875, &#34;y&#34;: 0.059225189617621805}}, {&#34;key&#34;: 7, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;7&#34;, &#34;size&#34;: 4, &#34;x&#34;: 0.24188272197116711, &#34;y&#34;: -0.13412354680599206}}, {&#34;key&#34;: 8, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;8&#34;, &#34;size&#34;: 5, &#34;x&#34;: -0.0780212865778704, &#34;y&#34;: 0.04684991911084784}}, {&#34;key&#34;: 9, &#34;attributes&#34;: {&#34;club&#34;: &#34;Officer&#34;, &#34;label&#34;: &#34;9&#34;, &#34;size&#34;: 2, &#34;x&#34;: -0.24366418254766045, &#34;y&#34;: -0.3736951152090227}}, {&#34;key&#34;: 10, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;10&#34;, &#34;size&#34;: 3, &#34;x&#34;: 0.6699516875342132, &#34;y&#34;: 0.28132381099183645}}, {&#34;key&#34;: 11, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;11&#34;, &#34;size&#34;: 1, &#34;x&#34;: 0.6814023481677938, &#34;y&#34;: -0.1271432551799443}}, {&#34;key&#34;: 12, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;12&#34;, &#34;size&#34;: 2, &#34;x&#34;: 0.47008805916658875, &#34;y&#34;: -0.4047397960857069}}, {&#34;key&#34;: 13, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;13&#34;, &#34;size&#34;: 5, &#34;x&#34;: 0.08836967476808702, &#34;y&#34;: -0.015595902762244067}}, {&#34;key&#34;: 14, &#34;attributes&#34;: {&#34;club&#34;: &#34;Officer&#34;, &#34;label&#34;: &#34;14&#34;, &#34;size&#34;: 2, &#34;x&#34;: -0.5607560679909829, &#34;y&#34;: 0.27250011913732386}}, {&#34;key&#34;: 15, &#34;attributes&#34;: {&#34;club&#34;: &#34;Officer&#34;, &#34;label&#34;: &#34;15&#34;, &#34;size&#34;: 2, &#34;x&#34;: -0.5593007237348834, &#34;y&#34;: 0.03104942647362269}}, {&#34;key&#34;: 16, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;16&#34;, &#34;size&#34;: 2, &#34;x&#34;: 1.0, &#34;y&#34;: 0.14626161801362186}}, {&#34;key&#34;: 17, &#34;attributes&#34;: {&#34;club&#34;: &#34;Mr. Hi&#34;, &#34;label&#34;: &#34;17&#34;, &#34;size&#34;: 2, &#34;x&#34;: 0.5531057400875502, &#34;y&#34;: -0.20948557338623708}}, {&#34;key&#34;: 18, &#34;attributes&#34;: {&#34;club&#34;: &#34;Officer&#34;, &#34;label&#34;: &#34;18&#34;, &#34;size&#34;: 2, &#34;x ...

# %% [markdown]
# Check out [Networks](../../reference/display-blocks/network/) in the API Reference.

# %% [markdown]
# ## Text And HTML
#
# Whether you need to embed markdown, a code block:

# %%
code = """
function foo(n) {
  return foo(n + 1)
}
"""

ar.Code(code=code, language="javascript")
# Out:
# <style>
#   #ar-a9ca4d5785fc44c08b9d56848d4394c0 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-a9ca4d5785fc44c08b9d56848d4394c0" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;a9ca4d5785fc44c08b9d56848d4394c0&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;content&#34;: &#34;function foo(n) {\n  return foo(n + 1)\n}&#34;, &#34;language&#34;: &#34;javascript&#34;, &#34;_tag&#34;: &#34;Code&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-a9ca4d5785fc44c08b9d56848d4394c0");
# </script>

# %% [markdown]
# Use an alert block to highlight important markdown content or messages:

# %%
ar.Alert("This is an alert", mode=ar.AlertMode.WARNING)
# Out:
# <style>
#   #ar-9c45d83e95944993a3d5baf5932eb01b {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-9c45d83e95944993a3d5baf5932eb01b" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;9c45d83e95944993a3d5baf5932eb01b&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;content&#34;: &#34;This is an alert&#34;, &#34;border&#34;: true, &#34;mode&#34;: &#34;WARNING&#34;, &#34;_tag&#34;: &#34;Alert&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-9c45d83e95944993a3d5baf5932eb01b");
# </script>

# %% [markdown]
# Present a LaTeX formula, or HTML:

# %%
html = """
<html>
    <style type='text/css'>
        @keyframes example {
            0%   {color: #EEE;}
            25%  {color: #EC4899;}
            50%  {color: #8B5CF6;}
            100% {color: #EF4444;}
        }
        #container {
            background: #1F2937;
            padding: 10em;
        }
        h1 {
            color:#eee;
            animation-name: example;
            animation-duration: 4s;
            animation-iteration-count: infinite;
        }
    </style>
    <div id="container">
      <h1> Welcome to my App </h1>
    </div>
</html>
"""

ar.HTML(html)
# Out:
# <style>
#   #ar-1fb06c746a9f4ebea370d72828b63bac {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-1fb06c746a9f4ebea370d72828b63bac" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;1fb06c746a9f4ebea370d72828b63bac&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;content&#34;: &#34;\u003chtml\u003e\n    \u003cstyle type=\u0027text/css\u0027\u003e\n        @keyframes example {\n            0%   {color: #EEE;}\n            25%  {color: #EC4899;}\n            50%  {color: #8B5CF6;}\n            100% {color: #EF4444;}\n        }\n        #container {\n            background: #1F2937;\n            padding: 10em;\n        }\n        h1 {\n            color:#eee;\n            animation-name: example;\n            animation-duration: 4s;\n            animation-iteration-count: infinite;\n        }\n    \u003c/style\u003e\n    \u003cdiv id=\&#34;container\&#34;\u003e\n      \u003ch1\u003e Welcome to my App \u003c/h1\u003e\n    \u003c/div\u003e\n\u003c/html\u003e&#34;, &#34;sandbox&#34;: &#34;allow-scripts&#34;, &#34;_tag&#34;: &#34;HTML&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-1fb06c746a9f4ebea370d72828b63bac");
# </script>

# %% [markdown]
# Check out [Text and HTML](../../reference/display-blocks/text/) in the API Reference for further details and more examples.
#
# ## Media And Embeds
#
# There are often cases where you need to include an external image:

# %%
ar.Media(file="./image.png", name="Image1", caption="Arakawa in action!")
# Out:
# <style>
#   #ar-94cd0cea0bd14653a7fd8ba95cb8f689 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-94cd0cea0bd14653a7fd8ba95cb8f689" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;94cd0cea0bd14653a7fd8ba95cb8f689&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;caption&#34;: &#34;Arakawa in action!&#34;, &#34;src&#34;: &#34;ref://ae5aa9fc37&#34;, &#34;type&#34;: &#34;image/png&#34;, &#34;_tag&#34;: &#34;Media&#34;, &#34;id&#34;: &#34;Image1&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {&#34;ae5aa9fc37&#34;: {&#34;src&#34;: &#34;data:image/png;base64,...&#34;, &#34;hash&#34;: &#34;ae5aa9fc37&#34;, &#34;size&#34;: 248992, &#34;mime&#34;: &#34;image/png&#34;}}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-94cd0cea0bd14653a7fd8ba95cb8f689");
# </script>

# %% [markdown]
# Or attach a file that your user can download:

# %%
data_path = "./netflix_stock_data.csv"

ar.Attachment(file=data_path)
# Out:
# <style>
#   #ar-c35703675dda4497b92dcef03a902d46 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-c35703675dda4497b92dcef03a902d46" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;c35703675dda4497b92dcef03a902d46&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;src&#34;: &#34;ref://5cf3b1853e&#34;, &#34;type&#34;: &#34;text/csv&#34;, &#34;filename&#34;: &#34;netflix_stock_data.csv&#34;, &#34;_tag&#34;: &#34;Attachment&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {&#34;5cf3b1853e&#34;: {&#34;src&#34;: &#34;data:text/csv;base64,...&#34;, &#34;hash&#34;: &#34;5cf3b1853e&#34;, &#34;size&#34;: 45340, &#34;mime&#34;: &#34;text/csv&#34;}}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-c35703675dda4497b92dcef03a902d46");
# </script>

# %% [markdown]
# Check out [Media and embeds](../../reference/display-blocks/embeds/) in the API Reference.
#
# ## Automatic Conversion
#
# As well as explicitly specifying your block type (for instance, by using `ar.Plot`), Arakawa will try and choose the best block for your object if you pass it in directly.
#
# The defaults are as follows:
#
# | Object Type           | Arakawa Block |
# | --------------------- | -------------- |
# | pandas DataFrame      | `ar.Table` (up to 100 cells),<br> `ar.DataTable` (over 100 cells) |
# | string                | `ar.Text`      |
# | Altair                | `ar.Plot`      |
# | Bokeh                 | `ar.Plot`      |
# | Folium                | `ar.Plot`      |
# | Matplotlib / Seaborn  | `ar.Plot`      |
# | Plotly                | `ar.Plot`      |
# | NetworkX              | `ar.NetworkX`      |
