# %% [markdown]
# # Quickstart
#
# These instructions will help you create a report in <1 minute. We will build a simple HTML report using Python based on the [Iris dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set).
#
# ## Installation
#
# First, install Arakawa using `pip` or `conda`. Check out our [installation page](../installing-arakawa/) for installation options.
#
# ```python
# pip3 install -U arakawa
# ```

# %% [markdown]
# ## Setting Things Up

# %%
import altair as alt
import arakawa as ar
from vega_datasets import data

# %% [markdown]
# We've imported `arakawa`, the popular visualization library `altair`, and `vega_datasets` which contains some sample datasets.
#
# Let's load the Iris dataset and get a list of the features.

# %%
df = data.iris()
columns = list(df.columns)
print(columns)
# Out:
# ['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth', 'species']

# %% [markdown]
# ## Blocks
#
# Your report is comprised of _Blocks_, which are Python objects that wrap around common objects such as datasets, plots, and other blocks. There are display blocks, such as _Plot_ or _DataTable_, and layout blocks, such as _Select_ and _Group_.
#
# Having loaded our DataFrame above and with knowledge of our column names, we first create a simple scatterplot using the Altair plotting library.
#
# We then build a simple set of blocks which presents two tabs: one with our plot, and one with our DataFrame.

# %%
fig = (
    alt.Chart(df)
    .mark_point()
    .encode(x=alt.X("sepalLength", scale=alt.Scale(zero=False)),
            y=alt.X("sepalWidth", scale=alt.Scale(zero=False)),
            color="species")
)

view = ar.Select(ar.Plot(fig, label="Plot"), ar.DataTable(df, label="Data"))
view
# Out:
# <style>
#   #ar-f7e3248beaeb4f49a3f40394496de4a1 {
#     width: 1px;
#     min-width: 100%;
#   }
# </style>
# <iframe id="ar-f7e3248beaeb4f49a3f40394496de4a1" style="border: none;"
#   srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&#34;en&#34;&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&#34;UTF-8&#34; /&gt;
#
# &lt;link href=&#34;https://fonts.googleapis.com/css?family=Inter:400,500,600,700|Inconsolata|Karla|Rubik&amp;display=swap&#34;
#   rel=&#34;stylesheet&#34; /&gt;
#
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.css&#34; /&gt;
# &lt;link rel=&#34;stylesheet&#34; href=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/tailwind.css&#34; /&gt;
#
# &lt;script&gt;
#   window.arLocal = true;
#   /* construct the view */
#   const htmlHeader = `&lt;style type=&#34;text/css&#34;&gt;:root {
#     --ar-accent-color: #4E46E5;
#     --ar-bg-color: #FFF;
#     --ar-text-align: left;
#     --ar-font-family: Inter, ui-sans-serif, system-ui;
# }&lt;/style&gt;`;
#   window.reportProps = {
#     id: &#34;f7e3248beaeb4f49a3f40394496de4a1&#34;,
#     htmlHeader,
#     isLightProse: false,
#   mode: &#34;VIEW&#34;,
#     reportWidthClass: &#34;max-w-screen-xl&#34;
#   };
#   window.reportProps[&#34;appData&#34;] = {&#34;data&#34;: {&#34;result&#34;: {&#34;viewJson&#34;: {&#34;blocks&#34;: [{&#34;blocks&#34;: [{&#34;label&#34;: &#34;Plot&#34;, &#34;src&#34;: &#34;ref://184fa535e3&#34;, &#34;type&#34;: &#34;application/vnd.vegalite.v5+json&#34;, &#34;responsive&#34;: true, &#34;scale&#34;: 1.0, &#34;_tag&#34;: &#34;Plot&#34;}, {&#34;label&#34;: &#34;Data&#34;, &#34;src&#34;: &#34;ref://b9f51c92e2&#34;, &#34;type&#34;: &#34;application/vnd.apache.arrow+binary&#34;, &#34;rows&#34;: 150, &#34;columns&#34;: 5, &#34;_tag&#34;: &#34;DataTable&#34;}], &#34;type&#34;: &#34;tabs&#34;, &#34;_tag&#34;: &#34;Select&#34;}], &#34;fragment&#34;: false, &#34;version&#34;: &#34;0.4.4&#34;, &#34;_tag&#34;: &#34;View&#34;}, &#34;assets&#34;: {&#34;184fa535e3&#34;: {&#34;src&#34;: &#34;data:application/vnd.vegalite.v5+json;base64,...&#34;, &#34;hash&#34;: &#34;184fa535e3&#34;, &#34;size&#34;: 21632, &#34;mime&#34;: &#34;application/vnd.vegalite.v5+json&#34;}, &#34;b9f51c92e2&#34;: {&#34;src&#34;: &#34;data:application/vnd.apache.arrow+binary;base64,...&#34;, &#34;hash&#34;: &#34;b9f51c92e2&#34;, &#34;size&#34;: 10808, &#34;mime&#34;: &#34;application/vnd.apache.arrow+binary&#34;}}}}};
# &lt;/script&gt;
#
# &lt;script type=&#34;module&#34;&gt;
#   import { mountReport } from &#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js&#34;;
#   mountReport(window.reportProps);
# &lt;/script&gt;
#
# &lt;/head&gt;
# &lt;script&gt;
#   window.isIPythonEmbed = true;
# &lt;/script&gt;
#
# &lt;body&gt;
#   &lt;main class=&#34;max-w-screen-xl w-full mx-auto&#34;&gt;
#     &lt;div id=&#34;report&#34; class=&#34;w-full&#34;&gt;&lt;/div&gt;
#   &lt;/main&gt;
#   &lt;script src=&#34;https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/assets/index.umd.js&#34;&gt;&lt;/script&gt;
# &lt;/body&gt;
#
# &lt;/html&gt;">
# </iframe>
# <script type="module">
#   import { iframeResize } from "https://cdn.jsdelivr.net/npm/arakawa@0.4.4/dist/report/index.js";
#   iframeResize({ log: true, checkOrigin: false, license: "GPLv3" }, "#ar-f7e3248beaeb4f49a3f40394496de4a1");
# </script>

# %% [markdown]
# ## Reports
#
# Once we have a view, we can save it as an HTML report to share.
#
# Let's save it as a report and [open it in a new window](./quickstart_report.html){:target=_blank}.

# %%
ar.save_report(view, "quickstart_report.html", open=True)
# or
ar.Report(view).save("quickstart_report.html", open=True)
# Out:
# App saved to ./quickstart_report.html
# App saved to ./quickstart_report.html

# %% [markdown]
# ## Sharing Your Report
#
# That's it! As Arakawa has created an HTML file, you can now share this Slack or email without deploying any code or configuring a backend server.
